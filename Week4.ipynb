# %%
data=pandas.read_csv("vh_data15.csv")
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 data=pandas.read_csv("vh_data15.csv")
#       2 data
#
# NameError: name 'pandas' is not defined

# %%
import pandas

# %%
data=pandas.read_csv("vh_data15.csv")

# %%
data
# Out:
#       County_Density  Vaccine_Trust_Index  Personal_Responsibility  \
# 0         137.851795             0.000000                     10.0
# 1          38.751406             9.000000                      5.0
# 2          18.103752             8.666667                      7.0
# 3          26.912917             4.000000                      7.0
# 4        1541.026670             7.000000                      6.0
# ...              ...                  ...                      ...
# 3348      470.033815             1.666667                      8.0
# 3349      225.323560             9.333333                      2.0
# 3350      108.474026             9.000000                      8.0
# 3351       63.385677             9.333333                      5.0
# 3352      599.558111             9.000000                     10.0
#
#       Trust_Science_Apolitical  Trust_Science_Politicians  \
# 0                          5.0                        5.0
# ...

# %%
data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
data.shape
# Out:
# (3353, 42)

# %%
data.isna()
# Out:
#       County_Density  Vaccine_Trust_Index  Personal_Responsibility  \
# 0              False                False                    False
# 1              False                False                    False
# 2              False                False                    False
# 3              False                False                    False
# 4              False                False                    False
# ...              ...                  ...                      ...
# 3348           False                False                    False
# 3349           False                False                    False
# 3350           False                False                    False
# 3351           False                False                    False
# 3352           False                False                    False
#
#       Trust_Science_Apolitical  Trust_Science_Politicians  \
# 0                        False                      False
# ...

# %%
data.isna().sum()
# Out:
# County_Density                17
# Vaccine_Trust_Index            0
# Personal_Responsibility        6
# Trust_Science_Apolitical       9
# Trust_Science_Politicians      8
# Trust_Science_Media            7
# Trust_Science_Community        7
# Trust_National                 4
# Trust_State                    4
# Trust_Local                    2
# Trust_Media                    1
# Perceived_Risk                 4
# Perceived_Network_Risk         5
# Doctor_Comfort                 5
# Fear_Needles                   4
# Condition_Pregnancy          101
# Condition_Asthma             101
# Condition_Lung               101
# Condition_Diabetes           101
# Condition_Immune             101
# Condition_Obesity            101
# Condition_Heart              101
# Condition_Organ              101
# County_Cases                  17
# County_Cases2wk               17
# Male                           0
# Race                           0
# Age                            2
# ...

# %%
cleaned_data = data.dropna() 'cleaned_data = data.dropna(axis=0)- By default the axis is 0'

# %%
data.shape, cleaned_data.shape
# Out:
# ((3353, 42), (3153, 42))

# %%
cleaned_data = data.dropna(axis=1) 'This works on column instead of rows '

# %%
data.shape, cleaned_data.shape
# Out:
# ((3353, 42), (3353, 6))

# %%
cleaned_data = data.fillna(data.mean())
# Out:
# C:\Users\anoop\AppData\Local\Temp\ipykernel_15248\3526587987.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cleaned_data = data.fillna(data.mean())

# %%
cleaned_data = data.fillna(data.mean()).fillna("")
# Out:
# C:\Users\anoop\AppData\Local\Temp\ipykernel_15248\3685503869.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cleaned_data = data.fillna(data.mean()).fillna("")

# %%
cleaned_data.shape
# Out:
# (3353, 42)
